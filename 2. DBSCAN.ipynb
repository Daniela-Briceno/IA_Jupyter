# %% [markdown]
# # Algoritmo DBSCAN
# #### DBSCAN es un algoritmo de clustering no supervisado que agrupa datos según la densidad de puntos en el espacio.
# #### Es muy útil cuando los datos tienen formas irregulares o contienen ruido (outliers).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import datasets

# %% [markdown]
# #### Se cargan los datos

# %%
import pandas as pd

# Cargar los datos
df = pd.read_csv('AllData1.csv')
print(df.head())
# Out:
#    direccion_viento  humedad_relativa  radiacion_solar  temp_aire  vel_viento  \
# 0             206.5              60.0             31.0       18.6        10.2
# 1             194.1              55.0             30.3       20.3        10.2
# 2             186.4              47.2             25.1       20.0         9.0
# 3             170.5              54.8             15.8       16.0         9.2
# 4             156.8              47.3             10.6       14.7         8.5
#
#    mp10_val
# 0   22.5369
# 1   39.0410
# 2   43.8277
# 3   34.0361
# 4   32.6348

# %%
#Esto ayuda a detectar datos faltantes o errores.
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   direccion_viento  69 non-null     float64
#  1   humedad_relativa  69 non-null     float64
#  2   radiacion_solar   69 non-null     float64
#  3   temp_aire         69 non-null     float64
#  4   vel_viento        69 non-null     float64
#  5   mp10_val          69 non-null     float64
# dtypes: float64(6)
# memory usage: 3.4 KB
# None
#        direccion_viento  humedad_relativa  radiacion_solar  temp_aire  \
# count         69.000000         69.000000        69.000000  69.000000
# mean         185.181159         43.501449        22.375362  16.723188
# std           16.524165          9.161613         7.744076   2.591680
# min          142.300000         14.000000        10.600000  11.100000
# 25%          173.500000         37.700000        14.200000  14.600000
# 50%          187.800000         43.300000        22.700000  17.200000
# 75%          199.200000         48.700000        30.300000  18.800000
# max          208.700000         61.800000        34.300000  20.900000
#
#        vel_viento   mp10_val
# count   69.000000  69.000000
# mean    10.094203  37.498562
# std      0.979178   8.247895
# min      7.900000  22.536900
# 25%      9.500000  31.533300
# 50%     10.100000  35.974100
# 75%     10.800000  43.200000
# max     12.600000  57.000000
# direccion_viento    0
# humedad_relativa    0
# radiacion_solar     0
# temp_aire           0
# vel_viento          0
# mp10_val            0
# dtype: int64

# %%
# Visualización
import matplotlib.pyplot as plt
#Scatter es un diagrama de dispersión
plt.scatter(df['temp_aire'], df['vel_viento'])
plt.xlabel('temp_aire')
plt.ylabel('vel_viento')
plt.title('Scatter plot de los datos')
plt.show()

# %%
# Crear instancia de DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)

# Ajustar DBSCAN a los datos y obtener los clusters asignados
clusters = dbscan.fit_predict(df[['temp_aire', 'vel_viento']])

# Visualizar los datos con colores por cluster
plt.scatter(df['temp_aire'], df['vel_viento'], c=clusters, cmap='viridis')
plt.xlabel('temp_aire')
plt.ylabel('vel_viento')
plt.title('Scatter plot de los datos con colores por cluster')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ### Interpretación y Discusión:
# #### Los clusters identificados por DBSCAN se muestran en la visualización. Cada punto de datos se asigna a un cluster
# #### La pertinencia del método DBSCAN depende de la distribución de los datos y la naturaleza del problema.
